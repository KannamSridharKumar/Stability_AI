# %%
# %load_ext nb_black

# %%
import io
import os
import warnings
import random

from IPython.display import display
from PIL import Image
from stability_sdk import client
import stability_sdk.interfaces.gooseai.generation.generation_pb2 as generation

# %%
STABILITY_API_KEY = os.environ.get("STABILITY_API_KEY")

# %%
stability_api = client.StabilityInference(
    key=STABILITY_API_KEY, verbose=False, engine="stable-diffusion-v1-5",
)

# %%
# response = stability_api.generate(
#     prompt="expansive landscape rolling greens with blue daisies and weeping willow trees under a blue alien sky, artstation, masterful, ghibli",
#     seed=992446758,
#     steps=30,
#     cfg_scale=8.0,
#     width=512,
#     height=512,
#     samples=2,
#     sampler=generation.SAMPLER_K_DPMPP_2M,
# )

# %% [markdown]
# #### start_schedule
# - Skips a proportion of the start of the diffusion steps, allowing the init_image
#  to influence the final generated image.
# - Lower values will result in more influence from the init_image
# - Higher values will result in more influence from the diffusion steps.
# - A value of 0 would simply return you the  init_image
# - A value of 1 would return you a completely different image

# %%
img = Image.open("images/image_992446758.png")

# %%
response = stability_api.generate(
    prompt="expansive landscape rolling greens with blue daisies and weeping willow trees under a blue alien sky, artstation, masterful, ghibli",
    init_image=img,
    start_schedule=0.6,
    seed=123467458,
    steps=30,
    cfg_scale=8.0,
    width=512,
    height=512,
    samples=4,
    sampler=generation.SAMPLER_K_DPMPP_2S_ANCESTRAL,
)

# %%
for resp in response:
    for artifact in resp.artifacts:
        if artifact.finish_reason == generation.FILTER:
            warnings.warn("Safety filters activated")
        if artifact.type == generation.ARTIFACT_IMAGE:
            file_name = "images/image_" + str(artifact.seed) + ".png"
            print("image file name: ", file_name)
            with open(file_name, "wb") as image_file:
                image_file.write(artifact.binary)
            img2 = Image.open(io.BytesIO(artifact.binary))
            display(img2)
# Out:
# image file name:  images/image_1016388713.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F9D8AE11C70>
# image file name:  images/image_2536159393.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F9D8AE117C0>
# image file name:  images/image_123467458.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F9D782AFFA0>
# image file name:  images/image_3978045524.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F9D782AF310>

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F9D9A046E20>
